# %%
import matplotlib.pyplot as plt
import networkx as nx
import pandas as pd

allCategories = pd.read_csv("../categories.csv", index_col=0)
G = nx.read_gml("../GraphMissingEdges.gml")

# %%
degree = nx.degree_centrality(G)
sort_orders = sorted(degree.items(), key=lambda degree: degree[1], reverse=True)
# print(sort_orders)
top50 = sort_orders[:50]

dfDegree = pd.DataFrame(columns=['key','item','name','categories'])

print("Centralidade de grau")
for key,item in top50:
    cats = G.nodes[key]['categories'].split(",")
    categoriesString = []
    for cat in cats:
        categoriesString.append(allCategories.loc[int(cat)]['names'])

    dfDegree.loc[key] = pd.Series({'key':key ,'item':round(item,6), 'name':G.nodes[key]['name'], 'categories':", ".join(categoriesString)})

print(dfDegree)
# print(dfDegree.info())
# print(dfDegree.index)
dfDegree.to_csv('degreeCentrality.csv', sep=',', encoding='utf-8', index=False)
# Out:
# <class 'networkx.classes.graph.Graph'>
# Pai Northern Thai Kitchen
# Centralidade de proximidade
#                                            key      item  \
# r_BrIgzYcwo1NAuG9dLbpg  r_BrIgzYcwo1NAuG9dLbpg  0.349649
# iGEvDk6hsizigmXhDKs2Vg  iGEvDk6hsizigmXhDKs2Vg  0.325540
# hPXR-Bi8U-uz6TUViqmGpg  hPXR-Bi8U-uz6TUViqmGpg  0.323142
# 0a2O150ytxrDjDzXNfRWkA  0a2O150ytxrDjDzXNfRWkA  0.322582
# kOFDVcnj-8fd3doIpCQ06A  kOFDVcnj-8fd3doIpCQ06A  0.320239
# G24p1oGGfY3t-m8Z2lPCaQ  G24p1oGGfY3t-m8Z2lPCaQ  0.317758
# XYIPXJ9parr9FtvvcGI1SA  XYIPXJ9parr9FtvvcGI1SA  0.317549
# xL9EhlYVMSe2mdkisYjXog  xL9EhlYVMSe2mdkisYjXog  0.317094
# RtUvSWO_UZ8V3Wpj0n077w  RtUvSWO_UZ8V3Wpj0n077w  0.316556
# BYDs_o6U4CLxJec8k1Q90Q  BYDs_o6U4CLxJec8k1Q90Q  0.316373
# fNc1WuGwiT7RhqXUIe4S8A  fNc1WuGwiT7RhqXUIe4S8A  0.316214
# bLrjQj3G9NAyKoi5EROj1Q  bLrjQj3G9NAyKoi5EROj1Q  0.315800
# mZRKH9ngRY92bI_irrHq6w  mZRKH9ngRY92bI_irrHq6w  0.315776
# B70iTJjcPkuYn8ouUewWgw  B70iTJjcPkuYn8ouUewWgw  0.315024
# ...

# %%
betweenness = nx.betweenness_centrality(G)
sort_orders = sorted(betweenness.items(), key=lambda betweenness: betweenness[1], reverse=True)
# print(sort_orders)
top50 = sort_orders[:50]

dfBetweenness = pd.DataFrame(columns=['key','item','name','categories'])

print("Centralidade de proximidade")
for key,item in top50:
    cats = G.nodes[key]['categories'].split(",")
    categoriesString = []
    for cat in cats:
        categoriesString.append(allCategories.loc[int(cat)]['names'])

    dfBetweenness.loc[key] = pd.Series({'key':key ,'item':round(item,6), 'name':G.nodes[key]['name'], 'categories':", ".join(categoriesString)})

print(dfBetweenness)
# print(dfBetweenness.info())
# print(dfBetweenness.index)
dfBetweenness.to_csv('betweennessCentrality.csv', sep=',', encoding='utf-8', index=False)
# Out:
# Centralidade de proximidade
#                                            key      item  \
# r_BrIgzYcwo1NAuG9dLbpg  r_BrIgzYcwo1NAuG9dLbpg  0.053927
# iGEvDk6hsizigmXhDKs2Vg  iGEvDk6hsizigmXhDKs2Vg  0.017764
# hPXR-Bi8U-uz6TUViqmGpg  hPXR-Bi8U-uz6TUViqmGpg  0.014250
# XYIPXJ9parr9FtvvcGI1SA  XYIPXJ9parr9FtvvcGI1SA  0.013402
# G24p1oGGfY3t-m8Z2lPCaQ  G24p1oGGfY3t-m8Z2lPCaQ  0.013044
# JG9UpsFR6hrqQqsKh_RyaQ  JG9UpsFR6hrqQqsKh_RyaQ  0.012744
# 0a2O150ytxrDjDzXNfRWkA  0a2O150ytxrDjDzXNfRWkA  0.012591
# kOFDVcnj-8fd3doIpCQ06A  kOFDVcnj-8fd3doIpCQ06A  0.012419
# xL9EhlYVMSe2mdkisYjXog  xL9EhlYVMSe2mdkisYjXog  0.012151
# RtUvSWO_UZ8V3Wpj0n077w  RtUvSWO_UZ8V3Wpj0n077w  0.011654
# bLrjQj3G9NAyKoi5EROj1Q  bLrjQj3G9NAyKoi5EROj1Q  0.011580
# U4iqELk1IiqARpk5uJJOZg  U4iqELk1IiqARpk5uJJOZg  0.011478
# B70iTJjcPkuYn8ouUewWgw  B70iTJjcPkuYn8ouUewWgw  0.010614
# fNc1WuGwiT7RhqXUIe4S8A  fNc1WuGwiT7RhqXUIe4S8A  0.009910
# uAAWlLdsoUf872F1FKiX1A  uAAWlLdsoUf872F1FKiX1A  0.009894
# ...

# %%
closeness = nx.closeness_centrality(G)
sort_orders = sorted(closeness.items(), key=lambda closeness: closeness[1], reverse=True)
# print(sort_orders)
top50 = sort_orders[:50]

dfCloseness = pd.DataFrame(columns=['key','item','name','categories'])

print("Centralidade de proximidade")
for key,item in top50:
    cats = G.nodes[key]['categories'].split(",")
    categoriesString = []
    for cat in cats:
        categoriesString.append(allCategories.loc[int(cat)]['names'])

    dfCloseness.loc[key] = pd.Series({'key':key ,'item':round(item,6), 'name':G.nodes[key]['name'], 'categories':", ".join(categoriesString)})

print(dfCloseness)
# print(dfCloseness.info())
# print(dfCloseness.index)
dfCloseness.to_csv('closenessCentrality.csv', sep=',', encoding='utf-8', index=False)
# Out:
# Centralidade de proximidade
#                                            key      item  \
# r_BrIgzYcwo1NAuG9dLbpg  r_BrIgzYcwo1NAuG9dLbpg  0.227684
# iGEvDk6hsizigmXhDKs2Vg  iGEvDk6hsizigmXhDKs2Vg  0.128519
# 0a2O150ytxrDjDzXNfRWkA  0a2O150ytxrDjDzXNfRWkA  0.117441
# hPXR-Bi8U-uz6TUViqmGpg  hPXR-Bi8U-uz6TUViqmGpg  0.113983
# kOFDVcnj-8fd3doIpCQ06A  kOFDVcnj-8fd3doIpCQ06A  0.101571
# bLrjQj3G9NAyKoi5EROj1Q  bLrjQj3G9NAyKoi5EROj1Q  0.098890
# 5m2JukTajxMk-qS5W4s-FA  5m2JukTajxMk-qS5W4s-FA  0.097308
# jc3p5SFyt9qrrMXt6E13ig  jc3p5SFyt9qrrMXt6E13ig  0.093737
# RtUvSWO_UZ8V3Wpj0n077w  RtUvSWO_UZ8V3Wpj0n077w  0.091700
# f5O7v_X_jCg2itqacRfxhg  f5O7v_X_jCg2itqacRfxhg  0.091353
# BYDs_o6U4CLxJec8k1Q90Q  BYDs_o6U4CLxJec8k1Q90Q  0.091211
# G24p1oGGfY3t-m8Z2lPCaQ  G24p1oGGfY3t-m8Z2lPCaQ  0.090891
# xL9EhlYVMSe2mdkisYjXog  xL9EhlYVMSe2mdkisYjXog  0.087589
# XYIPXJ9parr9FtvvcGI1SA  XYIPXJ9parr9FtvvcGI1SA  0.086455
# B70iTJjcPkuYn8ouUewWgw  B70iTJjcPkuYn8ouUewWgw  0.086094
# ...

# %%
eigenvector = nx.eigenvector_centrality(G)
sort_orders = sorted(eigenvector.items(), key=lambda eigenvector: eigenvector[1], reverse=True)
# print(sort_orders)
top50 = sort_orders[:50]

dfEigenvector = pd.DataFrame(columns=['key','item','name','categories'])

print("Centralidade de proximidade")
for key,item in top50:
    cats = G.nodes[key]['categories'].split(",")
    categoriesString = []
    for cat in cats:
        categoriesString.append(allCategories.loc[int(cat)]['names'])

    dfEigenvector.loc[key] = pd.Series({'key':key ,'item':round(item,6), 'name':G.nodes[key]['name'], 'categories':", ".join(categoriesString)})

print(dfEigenvector)
# print(dfEigenvector.info())
# print(dfEigenvector.index)
dfEigenvector.to_csv('eigenvectorCentrality.csv', sep=',', encoding='utf-8', index=False)

# %%
sort_orders = [('r_BrIgzYcwo1NAuG9dLbpg', 0.34964882062774716),
 ('iGEvDk6hsizigmXhDKs2Vg', 0.3255403734448956),
 ('hPXR-Bi8U-uz6TUViqmGpg', 0.3231416954105288),
 ('0a2O150ytxrDjDzXNfRWkA', 0.32258242881736265),
 ('kOFDVcnj-8fd3doIpCQ06A', 0.32023948954757353),
 ('G24p1oGGfY3t-m8Z2lPCaQ', 0.3177578785626646),
 ('XYIPXJ9parr9FtvvcGI1SA', 0.3175487140023159),
 ('xL9EhlYVMSe2mdkisYjXog', 0.3170944239965901),
 ('RtUvSWO_UZ8V3Wpj0n077w', 0.3165558763200606),
 ('BYDs_o6U4CLxJec8k1Q90Q', 0.3163726983961041),
 ('fNc1WuGwiT7RhqXUIe4S8A', 0.31621411558989054),
 ('bLrjQj3G9NAyKoi5EROj1Q', 0.31580011120273443),
 ('mZRKH9ngRY92bI_irrHq6w', 0.3157757917609569),
 ('B70iTJjcPkuYn8ouUewWgw', 0.3150237424739296),
 ('5m2JukTajxMk-qS5W4s-FA', 0.31427526682597473),
 ('f5O7v_X_jCg2itqacRfxhg', 0.3142391404637831),
 ('Yl2TN9c23ZGLUBSD9ks5Uw', 0.3134105204197581),
 ('Fx5haZv9PP3E7Ljp-h7B1Q', 0.3123124676424773),
 ('jc3p5SFyt9qrrMXt6E13ig', 0.312098530571367),
 ('e41TP5cXZqSrz50xCBJqZw', 0.3114111671852595),
 ('N_2yEZ41g9zDW_gWArFiHw', 0.3107974793581616),
 ('uAAWlLdsoUf872F1FKiX1A', 0.3097878248715223),
 ('h_4dPV9M9aYaBliH1Eoeeg', 0.3095656457732074),
 ('JG9UpsFR6hrqQqsKh_RyaQ', 0.3090523472951391),
 ('cQK9M2JAwETQnnBoYyua5A', 0.2861983279645371),
 ('o2uZemnFnlyEV0YDEiWBIw', 0.28608850512187994),
 ('O_UC_izJXcAmkm6HlEyGSA', 0.2860585680638952),
 ('-zuJkmIjdRahT_yHED-62g', 0.2860585680638952),
 ('s4c_f9WwcolJTNitq2gWpQ', 0.28604859043682634),
 ('eKznX8VTfcQrjCqXpeobiw', 0.28589900951102704),
 ('WRPlRsDK47DFl3dz65zhYg', 0.28587907720653294),
 ('Bppm5wvhLkppQ7cRu83dwg', 0.28571971876890256),
 ('5N8R7ALESZ30EoAzVJtabw', 0.28566995568565595),
 ('gHmkE8VoNjJZDLVdTpJPOw', 0.28565005530560117),
 ('9eu2lQMROTKdrPyGkwZLYw', 0.2856401061552649),
 ('bz07FlaDmxHV9ER-cF6XuA', 0.2856301576979594)]

top50 = sort_orders[:50]
# print(type(top50))

import networkx as nx
import pandas as pd

G = nx.read_gml("../GraphMissingEdges.gml")
allCategories = pd.read_csv("../categories.csv", index_col=0)

dfCentrality = pd.DataFrame(columns=['key','item','name','categories'])

print("Centralidade de proximidade")
for key,item in top50:
    cats = G.nodes[key]['categories'].split(",")
    categoriesString = []
    for cat in cats:
        categoriesString.append(allCategories.loc[int(cat)]['names'])

    dfCentrality.loc[key] = pd.Series({'key':key ,'item':item, 'name':G.nodes[key]['name'], 'categories':", ".join(categoriesString)})

print(dfCentrality)
print(dfCentrality.info())
print(dfCentrality.index)
dfCentrality.to_csv('closenessCentrality.csv', sep=',', encoding='utf-8', index=False)
# Out:
# Centralidade de proximidade
#                                            key      item  \
# r_BrIgzYcwo1NAuG9dLbpg  r_BrIgzYcwo1NAuG9dLbpg  0.349649
# iGEvDk6hsizigmXhDKs2Vg  iGEvDk6hsizigmXhDKs2Vg  0.325540
# hPXR-Bi8U-uz6TUViqmGpg  hPXR-Bi8U-uz6TUViqmGpg  0.323142
# 0a2O150ytxrDjDzXNfRWkA  0a2O150ytxrDjDzXNfRWkA  0.322582
# kOFDVcnj-8fd3doIpCQ06A  kOFDVcnj-8fd3doIpCQ06A  0.320239
# G24p1oGGfY3t-m8Z2lPCaQ  G24p1oGGfY3t-m8Z2lPCaQ  0.317758
# XYIPXJ9parr9FtvvcGI1SA  XYIPXJ9parr9FtvvcGI1SA  0.317549
# xL9EhlYVMSe2mdkisYjXog  xL9EhlYVMSe2mdkisYjXog  0.317094
# RtUvSWO_UZ8V3Wpj0n077w  RtUvSWO_UZ8V3Wpj0n077w  0.316556
# BYDs_o6U4CLxJec8k1Q90Q  BYDs_o6U4CLxJec8k1Q90Q  0.316373
# fNc1WuGwiT7RhqXUIe4S8A  fNc1WuGwiT7RhqXUIe4S8A  0.316214
# bLrjQj3G9NAyKoi5EROj1Q  bLrjQj3G9NAyKoi5EROj1Q  0.315800
# mZRKH9ngRY92bI_irrHq6w  mZRKH9ngRY92bI_irrHq6w  0.315776
# B70iTJjcPkuYn8ouUewWgw  B70iTJjcPkuYn8ouUewWgw  0.315024
# 5m2JukTajxMk-qS5W4s-FA  5m2JukTajxMk-qS5W4s-FA  0.314275
# ...
